# %%
import pandas as pd

gpa = pd.read_csv('gpa.csv')
gpa.columns
gpa.drop([' Ghi chú;;', ' Học kỳ', ' Lớp'], axis=1, inplace = True)
gpa
# Out:
#                                           Tên môn học   Số tín chỉ   Điểm  \
# 0                       CSC10001 - Nhập môn lập trình          4.0   10.0
# 1                   MTH00086 - Thực hành Toán rời rạc          1.0   10.0
# 2                MTH00081 - Thực hành Vi tích phân 1B          1.0    8.5
# 3                             MTH00041 - Toán rời rạc          3.0    7.0
# 4                          MTH00003 - Vi tích phân 1B          3.0    8.5
# 5                  ENV00003 - Con người và môi trường          2.0    9.5
# 6                        MTH00030 - Đại số tuyến tính          3.0    8.1
# 7           CSC10010 - Lập trình cho trí tuệ nhân tạo          4.0    8.0
# 8                      BAA00004 - Pháp luật đại cương          3.0    7.3
# 9              MTH00083 - Thực hành Đại số tuyến tính          1.0    9.0
# 10               MTH00082 - Thực hành Vi tích phân 2B          1.0    8.0
# 11                   BAA00101 - Triết học Mác - Lênin          3.0    8.0
# ...
