# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_excel('../Data/Data_finance_lab3.xlsx', sheet_name='data_final')
data.head()

# %%
_data = data.sample(frac=0.2, random_state=42)

for col in _data.columns:
    if col == 'RESULT_YES/NO':
        continue
    _data.loc[_data.sample(frac=0.1).index, col] = np.nan

_data.to_csv('../Data/demo_data.csv')
# Out:
# PRODUCT_NAME          100
# LA                    100
# TERM                  100
# COUNT_TERM_RECEIPT      0
# SUM_RECEIPT_AMT         0
# RESULT_YES/NO           0
# BAD_DEBT                0
# dtype: int64
